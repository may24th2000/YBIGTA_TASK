# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Import packages
# ---

# %%
'''
import modules
  - Basic tool
  - DL tool
  - OS tool
'''
# Basic tools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# DL tools
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical

# OS tool
import os

# %% [markdown]
# # Device Setting
# ---

# %%
'''
  Setting
    - Path setting to the current directory
    - GPU device setting (device: cuda)
'''

'''
# 뒤에 Model save&load를 위해 작업 directory를 my_PATH로 정의하였습니다.

# Path
my_PATH = "/content/drive/MyDrive/MLP_Assignment"
os.chdir(my_PATH)
# show file list in the current directory
# !dir

'''

'''
 (!!!!!!!!!!!!!!중요!!!!!!!!!!!!!!!!)
 GPU 설정을 해줘야 더 효율적인 학습이 가능합니다.
 "device: cuda"로 출력되면 Good!
 "device: cpu"일 경우 현재 코랩에서'런타임 → 런타임 유형 변경 → GPU' 설정을 해줍시다.
 코랩이 기본제공하는 GPU는 하루 최대 12시간 사용 가능합니다. 런타임이 연결되는 동안 시간이 차감됩니다.
 만약 코랩이 기본제공하는 GPU를 다 썼다면 약 하루를 기다리거나 다른 구글계정을 이용해야 합니다.
'''
# Device setting & configuration
# cuda가 available하면 cuda(GPU)로 아니면 CPU 연결
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('device:', device)
# Out:
# device: cuda

# %% [markdown]
# # Data Load
# ---

# %%
'''
  Load MNIST Data
    - Train & Validation & Test data
    - Image and Label
    - Min-Max scaling
'''
# Loading the data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Min-Max scaling (표준화 과정)
x_train = x_train/255.0
x_test = x_test/255.0

'''
 train_test_split은 sklearn으로 import한 모듈입니다.
 train_test_split을 통해 쉽게 데이터를 분리할 수 있습니다.
 이 코드는 train데이터를 0.8 : 0.2로 train과 validation 데이터로 분리하는 코드입니다,
 print 결과 Train 데이터는 28x28 사이즈의 이미지 데이터가 48,000장 있으며 이미지에 대응하는 label이 48,000개 존재함을 알 수 있습니다.
'''
# Split train data into Train/Validation data
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, shuffle=True)

# Check data shape
print(f"Train 데이터 크기: {x_train.shape, y_train.shape}")
print(f"Validation 데이터 크기: {x_val.shape, y_val.shape}")
print(f"Test 데이터 크기:{x_test.shape, y_test.shape}")
# Out:
# Train 데이터 크기: ((48000, 28, 28), (48000,))
# Validation 데이터 크기: ((12000, 28, 28), (12000,))
# Test 데이터 크기:((10000, 28, 28), (10000,))

# %%
# Check
fig = plt.figure(figsize=(18,8))
ax1 = fig.add_subplot(211)
img1 = plt.imshow(x_train[0].reshape(28, 28)).set_cmap('Greys')
ax2 = fig.add_subplot(222)
img2 = plt.imshow(x_train[1].reshape(28, 28)).set_cmap('Greys')
print(f"첫번째 이미지 라벨: {y_train[0]} ")
print(f"두번째 이미지 라벨: {y_train[1]} ")
# Out:
# 첫번째 이미지 라벨: 2
# 두번째 이미지 라벨: 7

# %%
'''
  Data Preparation
    - No augmentation
    - Min-Max scaling (already done at the first)
    - Label(target) -> One hot encoding

    MyDataset은 현재 데이터 set에 다음 속성들을 부여합니다.
    Pytorch의 DataLoader를 활용하기 위해 필요합니다.
'''

class Mydataset(torch.utils.data.Dataset):

    # 데이터 전처리
    def __init__(self, dataX_np , dataY_np):
        self.data_X = dataX_np.astype(np.float32)
        self.data_Y = dataY_np.astype(np.float32)

        print(f"My_dataset __init__ received : {self.data_X.shape}, {self.data_Y.shape} ")

    # 인덱스를 입력받아 인덱스에 알맞는 입출력 데이터를 출력
    def __getitem__(self, index):
        image = self.data_X[index]
        label = self.data_Y[index]
        # One hot encoding
        # 0~9 숫자로 되어있는 라벨을 one hot encoding 형식으로 변환합니다. 이는 이후 MLP의 출력이 10차원이기에 Loss를 계산하기 위해 진행하였습니다.
        label = to_categorical(label, num_classes = 10)

        return image, label

    # 총 데이터 개수를 Return
    def __len__(self):
        return len(self.data_X)

# %%
'''
 DataLoader는 데이터를 batch_size에 맞게 나눠주거나 shuffle해 주는 등의 기능을 지원합니다.
 DataLoader는 데이터를 index로 접근가능하도록 하고 for문에서 사용할 수 있는 iterable 객체로 감싸줍니다.

 batch_size 변수는 train 데이터의 batch 크기를 결정합니다.
 batch_size를 1로 할 경우 SGD가 되며 (모든 데이터의 배치크기가 1이므로 배치 = 하나의 데이터이기 때문입니다)
 batch_size를 현재 데이터의 수보다 같거나 크게 할 경우 BGD가 됩니다. (배치하나가 모든 데이터를 포함하기 때문입니다.)
 현재 batch_size를 32로 설정하였기에 48000//32 = 1500. 1500개의 배치가 생성되며 배치 한개당 32개의 이미지데이터와 라벨데이터가 존재합니다.
 drop_last = False로 설정하여 배치로 나눴을 때 32개가 채워지지 못하는 마지막 배치를 그대로 살리도록 하였습니다.

 train_loader의 경우 batch_size=32로 설정하여 Mini-batch Gradient Descent를 사용하도록 하였습니다.
 valid_lodaer와 test_loader의 batch_size를 데이터의 수보다 크게하여 모든 데이터에 대한 Loss와 Accuracy가 구해질 수 있도록 하였습니다.

 x_train, x_val, x_test 모두 (-1,28*28)로 reshape하였습니다. 즉, 28x28의 크기로 이뤄진 이미지 데이터를 28*28 = 784 차원의 벡터로 Flatten하였습니다.
 이미지 데이터를 일자로 폈다고 생각하시면 됩니다. 따라서 MLP 모델에 입력되는 데이터는 784차원의 벡터입니다.
'''

batch_size = 32
train_loader = torch.utils.data.DataLoader(Mydataset(x_train.reshape(-1,28*28), y_train), batch_size=batch_size, shuffle=False, drop_last = False)
valid_loader = torch.utils.data.DataLoader(Mydataset(x_val.reshape(-1,28*28), y_val), batch_size = 1000000000, shuffle=False, drop_last = False)
test_loader = torch.utils.data.DataLoader(Mydataset(x_test.reshape(-1,28*28), y_test), batch_size = 100000000, shuffle=False, drop_last = False)
# Out:
# My_dataset __init__ received : (48000, 784), (48000,)
# My_dataset __init__ received : (12000, 784), (12000,)
# My_dataset __init__ received : (10000, 784), (10000,)

# %% [markdown]
# # MLP Model
# ---

# %%
'''
  MLP 모델을 정의하는 Class 입니다.

  self.fc1 에서 fc1은 layer의 이름이며 fc1을 nn.Linear(input_dimension, output_dimension, bias=False)로 정의할 수 있습니다.
  즉 fc1은 784차원의 input을 wx+b의 Linear 함수를 적용하여 2048차원으로 보냅니다.(input 뉴런 784개, output 뉴런 2048개로 이뤄진 두 layer를 연결합니다.)
  bias를 True로 설정할 경우 bias를 추가할 수 있습니다.

'''
class MLP_overfit(nn.Module):
    def __init__(self):
        super(MLP_overfit, self).__init__()
        self.fc1 = nn.Linear(784, 2048)
        self.fc2 = nn.Linear(2048, 1024)
        self.fc3 = nn.Linear(1024, 512)
        self.fc4 = nn.Linear(512,256)
        self.fc5 = nn.Linear(256, 128)
        self.fc6 = nn.Linear(128, 64)
        self.fc7 = nn.Linear(64, 10)

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        x = F.relu(x)
        x = self.fc4(x)
        x = F.relu(x)
        x = self.fc5(x)
        x = F.relu(x)
        x = self.fc6(x)
        x = F.relu(x)
        x = self.fc7(x)

        # Pytorch에서는 Softmax가 CrossEntropy함수안에 내장되어 있기에 없어도 됩니다.
        # 이후 Loss를 CrossEntropy를 사용할 것이기에 제외하였습니다.
        # x = F.log_softmax(x, dim=1)

        return x

# %%
class MLP_underfit(nn.Module):
    def __init__(self):
        super(MLP_underfit, self).__init__()
        self.fc1 = nn.Linear(784, 32)  # 첫 번째 은닉층, 32개 뉴런 사용
        self.fc2 = nn.Linear(32, 16)  # 두 번째 은닉층, 16개 뉴런 사용
        self.fc3 = nn.Linear(16, 8)   # 세 번째 은닉층, 8개 뉴런 사용
        self.fc4 = nn.Linear(8, 10)   # 출력층, 10개 뉴런으로 분류 태스크에 맞게 설정

        # 가중치 초기화
        torch.nn.init.xavier_normal_(self.fc1.weight.data, gain=1.0)
        torch.nn.init.xavier_normal_(self.fc2.weight.data, gain=1.0)
        torch.nn.init.xavier_normal_(self.fc3.weight.data, gain=1.0)
        torch.nn.init.xavier_normal_(self.fc4.weight.data, gain=1.0)

    def forward(self, x):
        x = F.relu(self.fc1(x))  # ReLU 활성화 함수를 사용하여 첫 번째 은닉층을 거침
        x = F.relu(self.fc2(x))  # ReLU 활성화 함수를 사용하여 두 번째 은닉층을 거침
        x = F.relu(self.fc3(x))  # ReLU 활성화 함수를 사용하여 세 번째 은닉층을 거침
        x = self.fc4(x)          # 출력층으로 이동
        return x

# %% [markdown]
# # Train
# ---

# %%
from statistics import mean
import time

'''
 모델의 학습을 정의하는 함수입니다.
 model, Lossfunction, Optimizer, Scheduler 등을 입력받습니다.
 출력은 train, validation, test의 loss 리스트로 하였습니다.
 train함수를 사용하면 입력받은 loss와 optimizer, lr scheduler, num_epoch에 따라 model을 학습시킵니다.
'''

def train(model, criterion_, optimizer_, scheduler_, num_epochs=40, first_epoch=1):

    train_losses = []
    valid_losses = []
    test_losses = []

    print("----------------------------------------------------------------------------")

    start_time = time.time()
    for epoch in range(first_epoch, first_epoch + num_epochs):
        # train phase
        model.train()

        # batch_loss
        batch_losses = []

        for images, labels in train_loader:

            # Move the training data to the GPU
            images = images.to(device)
            labels = labels.to(device)

            # clear previous gradient computation
            optimizer_.zero_grad()

            # forward propagation
            outputs = model(images)

            # calculate the loss
            loss = criterion_.forward(outputs, labels)
            batch_losses.append(loss.item())

            # backpropagate to compute gradients
            loss.backward()

            # update model weights
            optimizer_.step()

        # Train loss를 저장합니다.
        train_losses.append(mean(batch_losses))

        # validation phase
        # Dropout, BatchNormalization과 같은 layer가 동작하지 않도록 합니다.
        model.eval()

        # We don't need gradients for test, so wrap in
        # no_grad to save memory
        # 기울기 Gradient를 계산하지 않으며 backpropagation을 하지 않습니다.
        with torch.no_grad():

            correct_test = 0

            for images, labels in valid_loader:

                # Move the training batch to the GPU
                images = images.to(device)
                labels = labels.to(device)

                # forward propagation
                outputs = model(images)

                # calculate the loss
                loss = criterion_(outputs, labels)
                valid_losses.append(loss.item())

            for images, labels in test_loader:
                # Move the training batch to the GPU
                images = images.to(device)
                labels = labels.to(device)

                # forward propagation
                outputs = model(images)

                # calculate the loss
                loss = criterion_(outputs, labels)
                test_losses.append(loss.item())

                # Check Accuracy
                # preds 는 output 중에서 가장 높은 값의 index를 가집니다.
                _, preds = torch.max(outputs, 1)

                # label이 현재 one hot encoding 형태로 되어있기에 preds를 index로 받아 1인지 확인합니다.
                # ex) 숫자 2 : label = [0,0,1,0,0,...,0] , label[i][preds] == 1 -> 정답
                for i in range(len(preds)):
                  if labels[i][preds[i]] == 1:
                    correct_test +=1

        # 원하는 Epoch마다 결과 출력
        if (epoch) % 1== 0 :
            curr_time = round(time.time()-start_time)
            train_rec = round(train_losses[-1],5)
            valid_rec = round(valid_losses[-1],5)
            test_rec = round(test_losses[-1],5)
            test_acc = round(100*(correct_test)/len(labels),3)
            print('Epoch', epoch, ' / ',num_epochs)
            print(f"\t [Train loss : {train_rec}]  [Validation loss : {valid_rec}] [Test loss : {test_rec}], [Test Accuracy : {test_acc}%],[curr LR = {scheduler_.get_last_lr()}],[elapsed_time = {curr_time}sec] ")

        # Learning rate Scheduling
        # Scheduler에 따라 learning rate를 조절합니다.
        scheduler_.step()


    print(f"\nTrain Ended, total_elapsed_time = {round(time.time()-start_time)} ")
    print("--------------------------------------------------------------------")

    # Loss 값 반환
    return train_losses, valid_losses, test_losses

# %% [markdown]
# ## Setting

# %%
# Model Setting
model = MLP_overfit()
model.to(device)

# Optimizer
# learning rate 기존 0.001에서 0.0001로 변경
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# Loss Function
criterion = nn.CrossEntropyLoss()

# Learning rate scheduler
# epoch가 10번 돌때마다 learning rate를 0.95만큼 곱함
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.95)

#Dropout
model.dropout = 0.0

#Batch size
batch_size = 1

#num epochs
num_epochs = 40

# %% [markdown]
# ## Training

# %% [markdown]
# ### Overfitting

# %%
train_losses, valid_losses, test_losses = train(model, criterion_ = criterion, optimizer_ = optimizer, scheduler_ = scheduler, num_epochs=num_epochs)
# Out:
# ----------------------------------------------------------------------------
# Epoch 1  /  40
# 	 [Train loss : 0.45018]  [Validation loss : 0.22175] [Test loss : 0.21018], [Test Accuracy : 93.8%],[curr LR = [0.0001]],[elapsed_time = 28sec]
# Epoch 2  /  40
# 	 [Train loss : 0.16384]  [Validation loss : 0.14753] [Test loss : 0.13418], [Test Accuracy : 96.03%],[curr LR = [0.0001]],[elapsed_time = 48sec]
# Epoch 3  /  40
# 	 [Train loss : 0.10561]  [Validation loss : 0.11616] [Test loss : 0.10272], [Test Accuracy : 96.88%],[curr LR = [0.0001]],[elapsed_time = 72sec]
# Epoch 4  /  40
# 	 [Train loss : 0.07205]  [Validation loss : 0.10448] [Test loss : 0.08874], [Test Accuracy : 97.35%],[curr LR = [0.0001]],[elapsed_time = 94sec]
# Epoch 5  /  40
# 	 [Train loss : 0.04873]  [Validation loss : 0.11183] [Test loss : 0.0946], [Test Accuracy : 97.53%],[curr LR = [0.0001]],[elapsed_time = 121sec]
# Epoch 6  /  40
# 	 [Train loss : 0.03482]  [Validation loss : 0.11815] [Test loss : 0.09161], [Test Accuracy : 97.65%],[curr LR = [0.0001]],[elapsed_time = 144sec]
# Epoch 7  /  40
# 	 [Train loss : 0.02708]  [Validation loss : 0.12367] [Test loss : 0.09931], [Test Accuracy : 97.53%],[curr LR = [0.0001]],[elapsed_time = 167sec]
# Epoch 8  /  40
# 	 [Train loss : 0.02226]  [Validation loss : 0.11828] [Test loss : 0.09976], [Test Accuracy : 97.51%],[curr LR = [0.0001]],[elapsed_time = 192sec]
# Epoch 9  /  40
# 	 [Train loss : 0.0173]  [Validation loss : 0.12694] [Test loss : 0.0984], [Test Accuracy : 97.85%],[curr LR = [0.0001]],[elapsed_time = 219sec]
# Epoch 10  /  40
# 	 [Train loss : 0.01571]  [Validation loss : 0.1345] [Test loss : 0.11237], [Test Accuracy : 97.68%],[curr LR = [0.0001]],[elapsed_time = 242sec]
# Epoch 11  /  40
# 	 [Train loss : 0.01235]  [Validation loss : 0.12543] [Test loss : 0.10615], [Test Accuracy : 97.8%],[curr LR = [9.5e-05]],[elapsed_time = 265sec]
# Epoch 12  /  40
# 	 [Train loss : 0.01225]  [Validation loss : 0.11567] [Test loss : 0.08932], [Test Accuracy : 98.04%],[curr LR = [9.5e-05]],[elapsed_time = 292sec]
# Epoch 13  /  40
# 	 [Train loss : 0.01117]  [Validation loss : 0.13061] [Test loss : 0.10665], [Test Accuracy : 97.79%],[curr LR = [9.5e-05]],[elapsed_time = 315sec]
# Epoch 14  /  40
# 	 [Train loss : 0.00981]  [Validation loss : 0.11884] [Test loss : 0.09048], [Test Accuracy : 98.04%],[curr LR = [9.5e-05]],[elapsed_time = 338sec]
# Epoch 15  /  40
# 	 [Train loss : 0.00759]  [Validation loss : 0.13248] [Test loss : 0.11576], [Test Accuracy : 97.85%],[curr LR = [9.5e-05]],[elapsed_time = 360sec]
# Epoch 16  /  40
# 	 [Train loss : 0.00758]  [Validation loss : 0.15398] [Test loss : 0.1242], [Test Accuracy : 97.49%],[curr LR = [9.5e-05]],[elapsed_time = 384sec]
# Epoch 17  /  40
# 	 [Train loss : 0.0063]  [Validation loss : 0.11924] [Test loss : 0.1008], [Test Accuracy : 98.14%],[curr LR = [9.5e-05]],[elapsed_time = 407sec]
# Epoch 18  /  40
# 	 [Train loss : 0.00767]  [Validation loss : 0.11881] [Test loss : 0.10609], [Test Accuracy : 98.01%],[curr LR = [9.5e-05]],[elapsed_time = 426sec]
# Epoch 19  /  40
# 	 [Train loss : 0.00756]  [Validation loss : 0.12046] [Test loss : 0.0931], [Test Accuracy : 98.22%],[curr LR = [9.5e-05]],[elapsed_time = 450sec]
# Epoch 20  /  40
# 	 [Train loss : 0.00658]  [Validation loss : 0.12782] [Test loss : 0.10165], [Test Accuracy : 98.18%],[curr LR = [9.5e-05]],[elapsed_time = 472sec]
# Epoch 21  /  40
# 	 [Train loss : 0.006]  [Validation loss : 0.125] [Test loss : 0.09856], [Test Accuracy : 98.14%],[curr LR = [9.025e-05]],[elapsed_time = 495sec]
# Epoch 22  /  40
# 	 [Train loss : 0.00665]  [Validation loss : 0.12472] [Test loss : 0.1013], [Test Accuracy : 98.09%],[curr LR = [9.025e-05]],[elapsed_time = 518sec]
# Epoch 23  /  40
# 	 [Train loss : 0.00398]  [Validation loss : 0.1425] [Test loss : 0.11172], [Test Accuracy : 98.11%],[curr LR = [9.025e-05]],[elapsed_time = 545sec]
# Epoch 24  /  40
# 	 [Train loss : 0.00551]  [Validation loss : 0.13355] [Test loss : 0.099], [Test Accuracy : 98.22%],[curr LR = [9.025e-05]],[elapsed_time = 568sec]
# Epoch 25  /  40
# 	 [Train loss : 0.00546]  [Validation loss : 0.13929] [Test loss : 0.10209], [Test Accuracy : 98.09%],[curr LR = [9.025e-05]],[elapsed_time = 591sec]
# Epoch 26  /  40
# 	 [Train loss : 0.00409]  [Validation loss : 0.12952] [Test loss : 0.10477], [Test Accuracy : 98.26%],[curr LR = [9.025e-05]],[elapsed_time = 619sec]
# Epoch 27  /  40
# 	 [Train loss : 0.00441]  [Validation loss : 0.14751] [Test loss : 0.14258], [Test Accuracy : 97.74%],[curr LR = [9.025e-05]],[elapsed_time = 643sec]
# Epoch 28  /  40
# 	 [Train loss : 0.00573]  [Validation loss : 0.12298] [Test loss : 0.10718], [Test Accuracy : 98.14%],[curr LR = [9.025e-05]],[elapsed_time = 666sec]
# Epoch 29  /  40
# 	 [Train loss : 0.00372]  [Validation loss : 0.12213] [Test loss : 0.10442], [Test Accuracy : 98.21%],[curr LR = [9.025e-05]],[elapsed_time = 689sec]
# Epoch 30  /  40
# 	 [Train loss : 0.00442]  [Validation loss : 0.13236] [Test loss : 0.10558], [Test Accuracy : 98.06%],[curr LR = [9.025e-05]],[elapsed_time = 715sec]
# Epoch 31  /  40
# 	 [Train loss : 0.00399]  [Validation loss : 0.12812] [Test loss : 0.09771], [Test Accuracy : 98.27%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 738sec]
# Epoch 32  /  40
# 	 [Train loss : 0.0022]  [Validation loss : 0.12732] [Test loss : 0.11195], [Test Accuracy : 98.31%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 760sec]
# Epoch 33  /  40
# 	 [Train loss : 0.00358]  [Validation loss : 0.15248] [Test loss : 0.11938], [Test Accuracy : 98.18%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 783sec]
# Epoch 34  /  40
# 	 [Train loss : 0.00368]  [Validation loss : 0.17519] [Test loss : 0.15183], [Test Accuracy : 97.73%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 806sec]
# Epoch 35  /  40
# 	 [Train loss : 0.00457]  [Validation loss : 0.12965] [Test loss : 0.11488], [Test Accuracy : 98.07%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 828sec]
# Epoch 36  /  40
# 	 [Train loss : 0.00164]  [Validation loss : 0.14047] [Test loss : 0.11011], [Test Accuracy : 98.24%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 851sec]
# Epoch 37  /  40
# 	 [Train loss : 0.00297]  [Validation loss : 0.14594] [Test loss : 0.12107], [Test Accuracy : 98.17%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 877sec]
# Epoch 38  /  40
# 	 [Train loss : 0.00303]  [Validation loss : 0.14011] [Test loss : 0.10679], [Test Accuracy : 98.38%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 900sec]
# Epoch 39  /  40
# 	 [Train loss : 0.00301]  [Validation loss : 0.13252] [Test loss : 0.1051], [Test Accuracy : 98.35%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 918sec]
# Epoch 40  /  40
# 	 [Train loss : 0.00192]  [Validation loss : 0.14444] [Test loss : 0.11416], [Test Accuracy : 98.2%],[curr LR = [8.573749999999999e-05]],[elapsed_time = 941sec]
#
# Train Ended, total_elapsed_time = 941
# --------------------------------------------------------------------

# %% [markdown]
# ### Underfitting

# %%
# Moodel Setting
model = MLP_underfit()
model.to(device)

# Optimizer
# 기존 Adam에서 SGD로 변경, learning rate 기존 0.001에서 0.0001로 변경
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# Loss Function
criterion = nn.CrossEntropyLoss()

# Learning rate scheduler
# epoch가 5번 돌때마다 learning rate를 0.3만큼 곱함
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.3)

# %%
train_losses_2, valid_losses_2, test_losses_2 = train(model, criterion_ = criterion, optimizer_ = optimizer, scheduler_ = scheduler, num_epochs=20)
# Out:
# ----------------------------------------------------------------------------
# Epoch 1  /  20
# 	 [Train loss : 1.47692]  [Validation loss : 0.86733] [Test loss : 0.83455], [Test Accuracy : 76.14%],[curr LR = [0.0001]],[elapsed_time = 25sec]
# Epoch 2  /  20
# 	 [Train loss : 0.67594]  [Validation loss : 0.55337] [Test loss : 0.52562], [Test Accuracy : 85.75%],[curr LR = [0.0001]],[elapsed_time = 45sec]
# Epoch 3  /  20
# 	 [Train loss : 0.4786]  [Validation loss : 0.42685] [Test loss : 0.40622], [Test Accuracy : 89.15%],[curr LR = [0.0001]],[elapsed_time = 65sec]
# Epoch 4  /  20
# 	 [Train loss : 0.38571]  [Validation loss : 0.3598] [Test loss : 0.34329], [Test Accuracy : 90.56%],[curr LR = [0.0001]],[elapsed_time = 86sec]
# Epoch 5  /  20
# 	 [Train loss : 0.33174]  [Validation loss : 0.31948] [Test loss : 0.30623], [Test Accuracy : 91.44%],[curr LR = [0.0001]],[elapsed_time = 110sec]
# Epoch 6  /  20
# 	 [Train loss : 0.30384]  [Validation loss : 0.30877] [Test loss : 0.29644], [Test Accuracy : 91.7%],[curr LR = [3e-05]],[elapsed_time = 130sec]
# Epoch 7  /  20
# 	 [Train loss : 0.29443]  [Validation loss : 0.30049] [Test loss : 0.28878], [Test Accuracy : 91.9%],[curr LR = [3e-05]],[elapsed_time = 150sec]
# Epoch 8  /  20
# 	 [Train loss : 0.28598]  [Validation loss : 0.29299] [Test loss : 0.28193], [Test Accuracy : 92.08%],[curr LR = [3e-05]],[elapsed_time = 166sec]
# Epoch 9  /  20
# 	 [Train loss : 0.27826]  [Validation loss : 0.28618] [Test loss : 0.2757], [Test Accuracy : 92.21%],[curr LR = [3e-05]],[elapsed_time = 186sec]
# Epoch 10  /  20
# 	 [Train loss : 0.27114]  [Validation loss : 0.27998] [Test loss : 0.27004], [Test Accuracy : 92.33%],[curr LR = [3e-05]],[elapsed_time = 206sec]
# Epoch 11  /  20
# 	 [Train loss : 0.26572]  [Validation loss : 0.2775] [Test loss : 0.26788], [Test Accuracy : 92.43%],[curr LR = [9e-06]],[elapsed_time = 226sec]
# Epoch 12  /  20
# 	 [Train loss : 0.2637]  [Validation loss : 0.27574] [Test loss : 0.26627], [Test Accuracy : 92.44%],[curr LR = [9e-06]],[elapsed_time = 252sec]
# Epoch 13  /  20
# 	 [Train loss : 0.26178]  [Validation loss : 0.27403] [Test loss : 0.26471], [Test Accuracy : 92.52%],[curr LR = [9e-06]],[elapsed_time = 268sec]
# Epoch 14  /  20
# 	 [Train loss : 0.25991]  [Validation loss : 0.27238] [Test loss : 0.26321], [Test Accuracy : 92.53%],[curr LR = [9e-06]],[elapsed_time = 288sec]
# Epoch 15  /  20
# 	 [Train loss : 0.25808]  [Validation loss : 0.27077] [Test loss : 0.26174], [Test Accuracy : 92.59%],[curr LR = [9e-06]],[elapsed_time = 308sec]
# Epoch 16  /  20
# 	 [Train loss : 0.25655]  [Validation loss : 0.27024] [Test loss : 0.26134], [Test Accuracy : 92.59%],[curr LR = [2.7e-06]],[elapsed_time = 329sec]
# Epoch 17  /  20
# 	 [Train loss : 0.25599]  [Validation loss : 0.26976] [Test loss : 0.26091], [Test Accuracy : 92.62%],[curr LR = [2.7e-06]],[elapsed_time = 348sec]
# Epoch 18  /  20
# 	 [Train loss : 0.25546]  [Validation loss : 0.26929] [Test loss : 0.26048], [Test Accuracy : 92.64%],[curr LR = [2.7e-06]],[elapsed_time = 369sec]
# Epoch 19  /  20
# 	 [Train loss : 0.25493]  [Validation loss : 0.26882] [Test loss : 0.26005], [Test Accuracy : 92.64%],[curr LR = [2.7e-06]],[elapsed_time = 389sec]
# Epoch 20  /  20
# 	 [Train loss : 0.25441]  [Validation loss : 0.26835] [Test loss : 0.25962], [Test Accuracy : 92.65%],[curr LR = [2.7e-06]],[elapsed_time = 409sec]
#
# Train Ended, total_elapsed_time = 409
# --------------------------------------------------------------------

# %% [markdown]
# # Plot Result
# ---

# %%
def plot_result(train_loss, val_loss, test_loss):
  plt.figure(figsize=(20,8))
  plt.plot(train_loss, label='Train Loss', linewidth='3')
  plt.plot(val_loss, label='Validation Loss', linewidth='3')
  plt.plot(test_loss, label='Test Loss', linewidth='3')
  plt.grid()
  plt.rc('xtick', labelsize=12)
  plt.rc('ytick', labelsize=12)
  plt.legend()
  plt.rc('legend', fontsize=15)
  plt.xlabel('Number of Epoch')
  plt.ylabel('Cross Entropy Loss')
  plt.rc('axes', labelsize=17)

# %% [markdown]
# #### Overfitting graph

# %%
plot_result(train_losses, valid_losses, test_losses)

# %% [markdown]
# #### Underfitting graph

# %%
plot_result(train_losses_2, valid_losses_2, test_losses_2)

# %% [markdown]
# * 최적점을 기준으로 좌측이 underfitting이 일어나는 구간이며, 우측이 overfitting이 일어나는 구간이다.

# %% [markdown]
# ![스크린샷 2023-07-18 오후 6.38.37.png](data:image/png;base64,...)

# %% [markdown]
# # Model Save & Load (참고용)
# ---

# %%
'''
  Modle Save & Load
'''
def save_model_info(model,model_name="ver_1", train_losses=train_losses, valid_losses=valid_losses, test_losses=test_losses):

    if not os.path.isdir("./models"):
        os.makedirs("./models")
    # 모델 정보 저장
    torch.save({'model_state_dict': model.state_dict(),
                'record_list' : [train_losses, valid_losses, test_losses]
                }, f"./models/model_{model_name}.pth")

    print(f"model_saved : model_{model_name}")


def load_model_info(model_name="ver_1"):

    file_path = f"./models/model_{model_name}.pth"


    if not os.path.exists(file_path):
        print("FATAL ERROR : model path not exist")
    model_info = torch.load(file_path)
    print(f"model_loaded : model_{model_name}")

    model = MLP_underfit()
    model.load_state_dict(model_info['model_state_dict'])
    model.to(device)
    model.eval()

    return model

# %%
save_model_info(model, "underfit", train_losses, valid_losses, test_losses)
# Out:
# model_saved : model_underfit

# %%
model = load_model_info("underfit")
# Out:
# model_loaded : model_underfit

# %% [markdown]
# # Generalized MLP

# %%
train_losses, valid_losses, test_losses = train(model, criterion_ = criterion, optimizer_ = optimizer, scheduler_ = scheduler, num_epochs=40)
# Out:
# ----------------------------------------------------------------------------
# Epoch 2  /  40
# 	 [Train loss : 0.40056]  [Validation loss : 0.13624] [Test loss : 0.13354], [Test Accuracy : 96.06%],[curr LR = [0.01]],[elapsed_time = 28sec]
# Epoch 3  /  40
# 	 [Train loss : 0.26954]  [Validation loss : 0.11601] [Test loss : 0.11241], [Test Accuracy : 96.53%],[curr LR = [0.01]],[elapsed_time = 46sec]
# Epoch 4  /  40
# 	 [Train loss : 0.2344]  [Validation loss : 0.10591] [Test loss : 0.10422], [Test Accuracy : 96.74%],[curr LR = [0.01]],[elapsed_time = 63sec]
# Epoch 5  /  40
# 	 [Train loss : 0.21876]  [Validation loss : 0.0961] [Test loss : 0.09744], [Test Accuracy : 96.99%],[curr LR = [0.01]],[elapsed_time = 86sec]
# Epoch 6  /  40
# 	 [Train loss : 0.20196]  [Validation loss : 0.08702] [Test loss : 0.08946], [Test Accuracy : 97.28%],[curr LR = [0.01]],[elapsed_time = 103sec]
# Epoch 7  /  40
# 	 [Train loss : 0.18681]  [Validation loss : 0.08408] [Test loss : 0.08766], [Test Accuracy : 97.17%],[curr LR = [0.01]],[elapsed_time = 120sec]
# Epoch 8  /  40
# 	 [Train loss : 0.17192]  [Validation loss : 0.08778] [Test loss : 0.09202], [Test Accuracy : 97.25%],[curr LR = [0.01]],[elapsed_time = 142sec]
# Epoch 9  /  40
# 	 [Train loss : 0.16259]  [Validation loss : 0.08483] [Test loss : 0.08793], [Test Accuracy : 97.42%],[curr LR = [0.01]],[elapsed_time = 159sec]
# Epoch 10  /  40
# 	 [Train loss : 0.16021]  [Validation loss : 0.08209] [Test loss : 0.08474], [Test Accuracy : 97.4%],[curr LR = [0.01]],[elapsed_time = 176sec]
# Epoch 11  /  40
# 	 [Train loss : 0.14935]  [Validation loss : 0.08011] [Test loss : 0.08567], [Test Accuracy : 97.6%],[curr LR = [0.01]],[elapsed_time = 194sec]
# Epoch 12  /  40
# 	 [Train loss : 0.11434]  [Validation loss : 0.07269] [Test loss : 0.07254], [Test Accuracy : 97.9%],[curr LR = [0.0005]],[elapsed_time = 211sec]
# Epoch 13  /  40
# 	 [Train loss : 0.09612]  [Validation loss : 0.06962] [Test loss : 0.06833], [Test Accuracy : 98.04%],[curr LR = [0.0005]],[elapsed_time = 232sec]
# Epoch 14  /  40
# 	 [Train loss : 0.08646]  [Validation loss : 0.06858] [Test loss : 0.06603], [Test Accuracy : 98.06%],[curr LR = [0.0005]],[elapsed_time = 249sec]
# Epoch 15  /  40
# 	 [Train loss : 0.08337]  [Validation loss : 0.06696] [Test loss : 0.06424], [Test Accuracy : 98.2%],[curr LR = [0.0005]],[elapsed_time = 266sec]
# Epoch 16  /  40
# 	 [Train loss : 0.0809]  [Validation loss : 0.06675] [Test loss : 0.06385], [Test Accuracy : 98.13%],[curr LR = [0.0005]],[elapsed_time = 280sec]
# Epoch 17  /  40
# 	 [Train loss : 0.07315]  [Validation loss : 0.06627] [Test loss : 0.06422], [Test Accuracy : 98.19%],[curr LR = [0.0005]],[elapsed_time = 299sec]
# Epoch 18  /  40
# 	 [Train loss : 0.07106]  [Validation loss : 0.06648] [Test loss : 0.0638], [Test Accuracy : 98.24%],[curr LR = [0.0005]],[elapsed_time = 316sec]
# Epoch 19  /  40
# 	 [Train loss : 0.06953]  [Validation loss : 0.06531] [Test loss : 0.0624], [Test Accuracy : 98.24%],[curr LR = [0.0005]],[elapsed_time = 343sec]
# Epoch 20  /  40
# 	 [Train loss : 0.06605]  [Validation loss : 0.06582] [Test loss : 0.06306], [Test Accuracy : 98.28%],[curr LR = [0.0005]],[elapsed_time = 363sec]
# Epoch 21  /  40
# 	 [Train loss : 0.06471]  [Validation loss : 0.06443] [Test loss : 0.06224], [Test Accuracy : 98.31%],[curr LR = [0.0005]],[elapsed_time = 376sec]
# Epoch 22  /  40
# 	 [Train loss : 0.06091]  [Validation loss : 0.06517] [Test loss : 0.06294], [Test Accuracy : 98.31%],[curr LR = [2.5e-05]],[elapsed_time = 394sec]
# Epoch 23  /  40
# 	 [Train loss : 0.06222]  [Validation loss : 0.06432] [Test loss : 0.06173], [Test Accuracy : 98.3%],[curr LR = [2.5e-05]],[elapsed_time = 412sec]
# Epoch 24  /  40
# 	 [Train loss : 0.06057]  [Validation loss : 0.0645] [Test loss : 0.06217], [Test Accuracy : 98.3%],[curr LR = [2.5e-05]],[elapsed_time = 431sec]
# Epoch 25  /  40
# 	 [Train loss : 0.06024]  [Validation loss : 0.06544] [Test loss : 0.06266], [Test Accuracy : 98.31%],[curr LR = [2.5e-05]],[elapsed_time = 453sec]
# Epoch 26  /  40
# 	 [Train loss : 0.06143]  [Validation loss : 0.06509] [Test loss : 0.06267], [Test Accuracy : 98.28%],[curr LR = [2.5e-05]],[elapsed_time = 470sec]
# Epoch 27  /  40
# 	 [Train loss : 0.0601]  [Validation loss : 0.06447] [Test loss : 0.06243], [Test Accuracy : 98.25%],[curr LR = [2.5e-05]],[elapsed_time = 488sec]
# Epoch 28  /  40
# 	 [Train loss : 0.06265]  [Validation loss : 0.06496] [Test loss : 0.06274], [Test Accuracy : 98.29%],[curr LR = [2.5e-05]],[elapsed_time = 514sec]
# Epoch 29  /  40
# 	 [Train loss : 0.06224]  [Validation loss : 0.06401] [Test loss : 0.06188], [Test Accuracy : 98.31%],[curr LR = [2.5e-05]],[elapsed_time = 533sec]
# Epoch 30  /  40
# 	 [Train loss : 0.05918]  [Validation loss : 0.06492] [Test loss : 0.06272], [Test Accuracy : 98.32%],[curr LR = [2.5e-05]],[elapsed_time = 553sec]
# Epoch 31  /  40
# 	 [Train loss : 0.0593]  [Validation loss : 0.06459] [Test loss : 0.06228], [Test Accuracy : 98.32%],[curr LR = [2.5e-05]],[elapsed_time = 576sec]
# Epoch 32  /  40
# 	 [Train loss : 0.06102]  [Validation loss : 0.06495] [Test loss : 0.06279], [Test Accuracy : 98.31%],[curr LR = [1.25e-06]],[elapsed_time = 595sec]
# Epoch 33  /  40
# 	 [Train loss : 0.05888]  [Validation loss : 0.06502] [Test loss : 0.06231], [Test Accuracy : 98.31%],[curr LR = [1.25e-06]],[elapsed_time = 617sec]
# Epoch 34  /  40
# 	 [Train loss : 0.05948]  [Validation loss : 0.06524] [Test loss : 0.06307], [Test Accuracy : 98.33%],[curr LR = [1.25e-06]],[elapsed_time = 635sec]
# Epoch 35  /  40
# 	 [Train loss : 0.0585]  [Validation loss : 0.06573] [Test loss : 0.06336], [Test Accuracy : 98.33%],[curr LR = [1.25e-06]],[elapsed_time = 655sec]
# Epoch 36  /  40
# 	 [Train loss : 0.05898]  [Validation loss : 0.06525] [Test loss : 0.06304], [Test Accuracy : 98.32%],[curr LR = [1.25e-06]],[elapsed_time = 676sec]
# Epoch 37  /  40
# 	 [Train loss : 0.06407]  [Validation loss : 0.06432] [Test loss : 0.06227], [Test Accuracy : 98.27%],[curr LR = [1.25e-06]],[elapsed_time = 694sec]
# Epoch 38  /  40
# 	 [Train loss : 0.05808]  [Validation loss : 0.06502] [Test loss : 0.06289], [Test Accuracy : 98.32%],[curr LR = [1.25e-06]],[elapsed_time = 712sec]
# Epoch 39  /  40
# 	 [Train loss : 0.06027]  [Validation loss : 0.06456] [Test loss : 0.06225], [Test Accuracy : 98.32%],[curr LR = [1.25e-06]],[elapsed_time = 735sec]
# Epoch 40  /  40
# 	 [Train loss : 0.06077]  [Validation loss : 0.06515] [Test loss : 0.06266], [Test Accuracy : 98.31%],[curr LR = [1.25e-06]],[elapsed_time = 755sec]
# Epoch 41  /  40
# 	 [Train loss : 0.06125]  [Validation loss : 0.06504] [Test loss : 0.06256], [Test Accuracy : 98.31%],[curr LR = [1.25e-06]],[elapsed_time = 774sec]
#
# Train Ended, total_elapsed_time = 774
# --------------------------------------------------------------------

# %%
plot_result(train_losses, valid_losses, test_losses)

# %% [markdown]
# Thanks to 21기 DS팀 이영환
